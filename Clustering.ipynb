# %% [markdown]
# # Goals
# * Use 1.5 years of data to train, and test on half a year of data to use KMeans Clustering to attempt to predict which customers will become High Value Customers.
# * A High Value customer will be in the top quintile for each RFM (recency, frequency, and monetary value) category.
#
# Much of this will have been done in Exploration.ipynb
